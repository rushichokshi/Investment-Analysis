# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
snp = pd.read_csv('../data/spy.csv')

# %%
snp.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1993-02-01  43.96875  45.12500  42.81250  44.40625  25.105677  5417600
# 1  1993-03-01  44.56250  45.84375  44.21875  45.18750  25.547392  3019200
# 2  1993-04-01  45.25000  45.25000  43.28125  44.03125  25.011251  2697200
# 3  1993-05-01  44.09375  45.65625  43.84375  45.21875  25.685791  1808000
# 4  1993-06-01  45.37500  45.81250  44.21875  45.06250  25.597042  3438000
# 5  1993-07-01  45.12500  45.21875  44.15625  44.84375  25.653311  6117600
# 6  1993-08-01  44.90625  46.56250  44.84375  46.56250  26.636541  5440100
# 7  1993-09-01  46.40625  46.59375  44.81250  45.93750  26.278999  4369900
# 8  1993-10-01  45.87500  47.15625  45.71875  46.84375  26.964390  6972900
# 9  1993-11-01  46.78125  47.00000  45.53125  46.34375  26.676571  5351100

# %%
snp.plot(x="Date",y="Adj Close",kind="line")
# Out:
# <Axes: xlabel='Date'>

# %%
re = pd.read_csv('../data/Real_Estate_Sales_2001-2020_GL.csv')
# Out:
# /var/folders/73/8ylhfl6151q5ccx79mch6ddc0000gn/T/ipykernel_19373/1265721790.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   re = pd.read_csv('../data/Real_Estate_Sales_2001-2020_GL.csv')

# %%
re.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        150500.0     325000.0       0.4630    Commercial              NaN
# 1        253000.0     430000.0       0.5883   Residential    Single Family
# 2        130400.0     179900.0       0.7248   Residential            Condo
# 3        619290.0     890000.0       0.6958   Residential    Single Family
# 4        862330.0    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# ...

# %%
# Amanda felt that housing might not be the best to compare to as finding the data may be difficult and it also might
# not be a complex enough project because you might be able to google search an article that sums up your project in
# one article. She also felt that it may be too subjective to make the capstone into an analysis in which you determine
# the best mix model for investment between the two. She suggests maybe also comparing stock market data with gold and
# crypto and doing an analysis on modernization: how has each investment performed historically, what is the volatility
# level of each, how have these investments performed during historical events/crises. She also suggested that maybe
# I can create a dashboard that shows how one's investment would perform as you change the mix of investments on the
# dashboard.

# %%
metro = pd.read_csv('../data/metro.csv')

# %%
metro.head()
# Out:
#    Period  Start Date    End Date  ZIP Code           Service District  \
# 0  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 1  2018Q2  06/21/2018  07/16/2018     37211    Urban Services District
# 2  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 3  2018Q2  06/21/2018  07/16/2018     37203    Urban Services District
# 4  2018Q1  02/01/2018  03/06/2018     37138  General Services District
#
#   Quality of Life Overall Feeling of Safety Neighborhood Safety  \
# 0         Neutral                   Neutral             Neutral
# 1       Satisfied                 Satisfied           Satisfied
# 2  Very Satisfied                   Neutral           Satisfied
# 3       Satisfied            Very Satisfied           Satisfied
# 4       Satisfied                 Satisfied           Satisfied
#
#   City Appearance Neighborhood Appearance  ... Race / Ethnicity - Black  \
# 0         Neutral               Satisfied  ...                      Yes
# ...

# %%
weekly = pd.read_csv('../data/weekly.csv')

# %%
weekly.head()
# Out:
#   week_end_date geo_country median_listing_price_yy active_listing_count_yy  \
# 0      9-Dec-23         usa                   1.50%                   4.00%
# 1      2-Dec-23         usa                   1.20%                   3.10%
# 2     25-Nov-23         usa                   1.20%                   1.80%
# 3     18-Nov-23         usa                   1.20%                   1.50%
# 4     11-Nov-23         usa                   0.70%                   0.60%
#
#    median_days_on_market_by_day_yy median_days_on_market_yy  \
# 0                               -4                   -6.30%
# 1                               -3                   -4.90%
# 2                               -2                   -3.40%
# 3                               -4                   -7.10%
# 4                               -2                   -3.80%
#
#   new_listing_count_yy new_listing_share_yy price_reduced_count_yy  \
# 0                6.80%                0.20%                 -6.90%
# ...

# %%
metromonthly = pd.read_csv('../data/metromonthly.csv')
# Out:
# /var/folders/73/8ylhfl6151q5ccx79mch6ddc0000gn/T/ipykernel_19373/1530414798.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   metromonthly = pd.read_csv('../data/metromonthly.csv')

# %%
metromonthly.cbsa_title.unique()
# Out:
# array(['New York-Newark-Jersey City, NY-NJ-PA',
#        'Los Angeles-Long Beach-Anaheim, CA',
#        'Chicago-Naperville-Elgin, IL-IN-WI',
#        'Dallas-Fort Worth-Arlington, TX',
#        'Houston-The Woodlands-Sugar Land, TX',
#        'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#        'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#        'Miami-Fort Lauderdale-Pompano Beach, FL',
#        'Atlanta-Sandy Springs-Alpharetta, GA',
#        'Boston-Cambridge-Newton, MA-NH', 'Phoenix-Mesa-Chandler, AZ',
#        'San Francisco-Oakland-Berkeley, CA',
#        'Detroit-Warren-Dearborn, MI', 'Seattle-Tacoma-Bellevue, WA',
#        'Minneapolis-St. Paul-Bloomington, MN-WI',
#        'Riverside-San Bernardino-Ontario, CA',
#        'Tampa-St. Petersburg-Clearwater, FL',
#        'Denver-Aurora-Lakewood, CO', 'San Diego-Chula Vista-Carlsbad, CA',
#        'St. Louis, MO-IL', 'Baltimore-Columbia-Towson, MD',
#        'Charlotte-Concord-Gastonia, NC-SC', 'Pittsburgh, PA',
# ...

# %%
zipmonthly = pd.read_csv('../data/zipmonthly.csv')
zipmonthly.head()
# Out:
# /var/folders/73/8ylhfl6151q5ccx79mch6ddc0000gn/T/ipykernel_19373/3370080684.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   zipmonthly = pd.read_csv('../data/zipmonthly.csv')
#   month_date_yyyymm postal_code        zip_name  median_listing_price  \
# 0            202311       11949  manorville, ny              644500.0
# 1            202311       35980      horton, al              394950.0
# 2            202311       22643     markham, va              735000.0
# 3            202311       26587      rachel, wv              195000.0
# 4            202311       61360      seneca, il              269800.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.0039                  -0.0444                  68.0
# 1                   0.0919                   0.3645                   6.0
# 2                   0.1760                      NaN                   3.0
# ...

# %%
zipmonthly[zipmonthly['zip_name']=='brentwood, tn'].sort_values('month_date_yyyymm',ascending=False)
# Out:
#         month_date_yyyymm postal_code       zip_name  median_listing_price  \
# 26585              202311       37027  brentwood, tn             1773250.0
# 30559              202310       37027  brentwood, tn             1799497.0
# 71136              202309       37027  brentwood, tn             1744950.0
# 102278             202308       37027  brentwood, tn             1589925.0
# 122398             202307       37027  brentwood, tn             1699000.0
# ...                   ...         ...            ...                   ...
# 2402015            201611       37027  brentwood, tn              787725.0
# 2425780            201610       37027  brentwood, tn              776900.0
# 2458959            201609       37027  brentwood, tn              784925.0
# 2477186            201608       37027  brentwood, tn              789450.0
# 2496427            201607       37027  brentwood, tn              770750.0
#
#          median_listing_price_mm  median_listing_price_yy  \
# ...

# %% [markdown]
# March 11, 2020: WHO announces COVID-19 is a pandemic.
#
# March 27, 2020: Congress passes CARES act.
#
# January 26, 2022: Feds announce plans to raise interest rates.
#
# March 16, 2022: Fed makes its first interest rate increase since 2018.
#
# June 2022: Inflation peaks at 9.1% per Consumer Price Index.
#
# July 27, 2023: Fed delivers its final rate increase.
