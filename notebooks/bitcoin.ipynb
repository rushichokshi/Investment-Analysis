# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
bitcoin = pd.read_csv('../data/bitcoin_daily.csv')

# %%
bitcoin_weekly = pd.read_csv('../data/bitcoin_weekly.csv')

# %%
bitcoin_monthly = pd.read_csv('../data/bitcoin_monthly.csv')

# %%
sns.lineplot(x=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Date'],y=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Adj Close'])
plt.grid(True)
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/73/8ylhfl6151q5ccx79mch6ddc0000gn/T/ipykernel_8749/2925300062.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(x=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Date'],y=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Adj Close'])
# /var/folders/73/8ylhfl6151q5ccx79mch6ddc0000gn/T/ipykernel_8749/2925300062.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(x=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Date'],y=bitcoin[bitcoin['Date']>='2020-03-01'][bitcoin['Date']<='2020-03-31']['Adj Close'])
